# %%
import torch
from matplotlib import pyplot as plt

# %%
losses_case_1=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-3_sobol_batch_1024_case_1\loss_logs.pth')
losses_case_2=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-3_sobol_batch_1024_case_2\loss_logs.pth')

# %%
losses_case_2.keys()
# Out:
# dict_keys(['loss_total', 'loss_phys', 'loss_data', 'loss_weights', 'Weights', 'diffusivity'])

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)


x=torch.linspace(0,10000,200)
plt.semilogy(x,losses_case_1['loss_data'][::50], label='Data Loss')
plt.semilogy(x,losses_case_1['loss_phys'][::50], label='PDE Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Case 1 losses')
plt.legend()
plt.grid(alpha=0.3)

plt.subplot(1,2,2)
plt.semilogy(x,losses_case_2['loss_data'][::50], label='Data Loss')
plt.semilogy(x,losses_case_2['loss_phys'][::50], label='PDE Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Case 2 losses')
plt.legend()
plt.grid(alpha=0.3)

# %%
plt.figure(figsize=(10,6))
plt.semilogy(losses_case_1['diffusivity'], label='Diffusivity case 1')
plt.semilogy(losses_case_2['diffusivity'], label='Diffusivity case 2')
plt.xlabel('Epochs')
plt.ylabel('Diffusivity')
plt.title('Diffusivity evolution for both cases')
plt.legend()
plt.grid(alpha=0.3)

# %%
print(f"Final diffusivity case 1: {losses_case_1['diffusivity'][8000]}| Final diffusivity case 2: {losses_case_2['diffusivity'][8000]}")
# Out:
# Final diffusivity case 1: 0.004302211571484804| Final diffusivity case 2: 0.018834702670574188

# %%
losses_case_1_lr=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-4_sobol_batch_1024_case_1\loss_logs.pth')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.semilogy(losses_case_1_lr['diffusivity'], label='Diffusivity case 1 lr=1e-4')
plt.semilogy(losses_case_1['diffusivity'], label='Diffusivity case 1 lr=1e-3')

plt.xlabel('Epochs')
plt.ylabel('Diffusivity')
plt.title('Diffusivity evolution for same case')
plt.legend()
plt.grid(alpha=0.3)

plt.subplot(1,2,2)
plt.semilogy(losses_case_1_lr['diffusivity'], label='Diffusivity case 1 lr=1e-4')
plt.xlabel('Epochs')
plt.ylabel('Diffusivity')
plt.title('Diffusivity evolution for lr=1e-4')
plt.legend()
plt.grid(alpha=0.3)

# %%
plt.figure(figsize=(10,6))
plt.semilogy(losses_case_1_lr['loss_data'], label='Data Loss lr=1e-4')
plt.semilogy(losses_case_1_lr['loss_phys'], label='PDE Loss lr=1e-4')

plt.semilogy(losses_case_1['loss_data'], label='Data Loss lr=1e-3',linestyle=":")
plt.semilogy(losses_case_1['loss_phys'], label='PDE Loss lr=1e-3',linestyle=":")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of losses between lr=1e-3 and lr=1e-4')
plt.legend()
plt.grid(alpha=0.3)

# %%
losses_1e3=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-3_sobol_batch_1024_case_1_1e-3_starting_point\loss_logs.pth')
losses_1e3_1e4=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-4_sobol_batch_1024_case_1_1e-3_starting_point\loss_logs.pth')

# %%
plt.figure(figsize=(10,6))
plt.semilogy(losses_1e3['diffusivity'], label='Diffusivity lr=1e-3 starting from 1e-3')
plt.semilogy(losses_1e3_1e4['diffusivity'], label='Diffusivity lr=1e-4 starting from 1e-3')
plt.xlabel('Epochs')
plt.ylabel('Diffusivity')
plt.title('Diffusivity evolution for different learning rates starting from same point')
plt.legend()
plt.grid(alpha=0.3)

# %%
print(f"Final diffusivity case 1: {losses_1e3['diffusivity'][-1]}| Final diffusivity case 2: {losses_1e3_1e4['diffusivity'][-1]}")
# Out:
# Final diffusivity case 1: 0.02113836258649826| Final diffusivity case 2: 0.006981334649026394

# %%
plt.figure(figsize=(10,6))
plt.semilogy(x,losses_1e3['loss_data'][::50], label='Data loss lr=1e-3 starting from 1e-3',linestyle=":")
plt.semilogy(x,losses_1e3['loss_phys'][::50], label='Phys loss lr=1e-3 starting from 1e-3',linestyle=":")

plt.semilogy(x,losses_1e3_1e4['loss_data'][::50], label='Data loss lr=1e-4 starting from 1e-3')
plt.semilogy(x,losses_1e3_1e4['loss_phys'][::50], label='Phys loss lr=1e-4 starting from 1e-3',)


plt.xlabel('Epochs')
plt.ylabel('Diffusivity')
plt.title('Diffusivity evolution for different learning rates starting from same point')
plt.legend()
plt.grid(alpha=0.3)

# %%
losses_1xdata=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-3_sobol_batch_1024_case_1\loss_logs.pth')
losses_2xdata=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_2xdata_IC_and_BC_lr_1e-3_sobol_batch_1024_case_1\loss_logs.pth')
losses_1xdata.keys()
# Out:
# dict_keys(['loss_total', 'loss_phys', 'loss_data', 'loss_weights', 'Weights', 'diffusivity'])

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
x=torch.linspace(0,10000,100)
plt.semilogy(x,losses_1xdata['loss_data'][::100], label='1x data')
plt.semilogy(x,losses_2xdata['loss_data'][::100], label='2x data')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of data loss for different amounts of data')
plt.grid(alpha=0.3)


plt.subplot(1,2,2)
plt.semilogy(x,losses_1xdata['loss_phys'][::100], label='1x data')
plt.semilogy(x,losses_2xdata['loss_phys'][::100], label='2x data')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of phys loss for different amounts of data')
plt.grid(alpha=0.3)

# %%
plt.figure(figsize=(20,6))
x=torch.linspace(0,10000,100)
plt.semilogy(losses_1xdata['diffusivity'], label='1x data')
plt.semilogy(losses_2xdata['diffusivity'], label='2x data')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of diffusivity estimation for different amounts of data')
plt.grid(alpha=0.3)

# %%
# Analyzing repeatability with different seeds
losses_1=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-4_sobol_batch_1024_case_1_1e-3_starting_point\loss_logs.pth')
losses_2=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-4_sobol_batch_1024_case_1_1e-3_starting_point_different_seed\loss_logs.pth')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
x=torch.linspace(0,10000,200)
plt.semilogy(x,losses_1['loss_data'][::50], label='Seed 0')
plt.semilogy(x,losses_2['loss_data'][::50], label='Seed 42')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of data loss for different starting seeds')
plt.grid(alpha=0.3)


plt.subplot(1,2,2)
plt.semilogy(x,losses_1['loss_phys'][::50], label='Seed 0')
plt.semilogy(x,losses_2['loss_phys'][::50], label='Seed 42')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of phys loss for different starting seeds')
plt.grid(alpha=0.3)

# %%
plt.figure(figsize=(20,6))
x=torch.linspace(0,10000,100)
plt.semilogy(losses_1['diffusivity'], label='Seed 0')
plt.semilogy(losses_2['diffusivity'], label='Seed 42')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of diffusivity estimation for different starting seeds')
plt.grid(alpha=0.3)

# %%
# decay og
losses_decay=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-3_sobol_batch_1024_case_1_1e-3_starting_point_decay\loss_logs.pth')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
x=torch.linspace(0,10000,200)
plt.semilogy(x,losses_1['loss_data'][::50], label='lr fixed 1e-4')
plt.semilogy(x,losses_decay['loss_data'][::50], label='lr decay')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of data loss for different learning rate strategies')
plt.grid(alpha=0.3)


plt.subplot(1,2,2)
plt.semilogy(x,losses_1['loss_phys'][::50], label='lr fixed 1e-4')
plt.semilogy(x,losses_decay['loss_phys'][::50], label='lr decay')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of phys loss for different learning rate strategies')
plt.grid(alpha=0.3)

# %%
plt.figure(figsize=(20,6))
x=torch.linspace(0,10000,100)
plt.semilogy(losses_1['diffusivity'], label='Seed 0 lr = 1e-4')
plt.semilogy(losses_2['diffusivity'], label='Seed 42 lr = 1e-4')
plt.semilogy(losses_decay['diffusivity'], label='lr decay')
plt.semilogy(losses_1e3['diffusivity'], label='Diffusivity lr = 1e-3')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of diffusivity estimation for different starting seeds')
plt.grid(alpha=0.3)

# %%
losses_decay_1=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-3_sobol_batch_1024_case_1_1_starting_point_decay\loss_logs.pth')

# %%
plt.figure(figsize=(20,6))
plt.semilogy(losses_case_1['diffusivity'], label='Diffusivity case 1 no decay')
plt.semilogy(losses_decay_1['diffusivity'], label='Diffusivity case 1 decay')
plt.xlabel('Epochs')
plt.ylabel('Diffusivity')
plt.title('Diffusivity evolution')
plt.legend()
plt.grid(alpha=0.3)

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)


x=torch.linspace(0,10000,200)
plt.semilogy(x,losses_case_1['loss_data'][::50], label='Data Loss')
plt.semilogy(x,losses_decay_1['loss_data'][::50], label='Data Loss decay')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Data losses')
plt.legend()
plt.grid(alpha=0.3)

plt.subplot(1,2,2)
plt.semilogy(x,losses_case_1['loss_phys'][::50], label='Phys Loss')
plt.semilogy(x,losses_decay_1['loss_phys'][::50], label='Phys Loss decay')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Phys losses')
plt.legend()
plt.grid(alpha=0.3)

# %%
# compare losses for both cases starting at same point

losses_1e4_case_1=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-4_sobol_batch_1024_case_1_1e-3_starting_point\loss_logs.pth')
losses_1e4_case_2=torch.load(r'C:\Users\stone\Anisotropic_diffusivity_2\Results_fixed_case_0.5_constant_sampled_data_IC_and_BC_lr_1e-4_sobol_batch_1024_case_2_1e-3_starting_point\loss_logs.pth')

# %%
plt.figure(figsize=(20,6))
plt.semilogy(losses_1e4_case_1['diffusivity'], label='Diffusivity case 1')
plt.semilogy(losses_1e4_case_2['diffusivity'], label='Diffusivity case 2')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Diffusivity evolution for both cases starting from same point at lr=1e-4')
plt.grid(alpha=0.3)

# %%
print(f"Final diffusivity case 1: {losses_1e4_case_1['diffusivity'][-1]}| Final diffusivity case 2: {losses_1e4_case_2['diffusivity'][-1]}")
# Out:
# Final diffusivity case 1: 0.006981334649026394| Final diffusivity case 2: 0.007126901298761368
