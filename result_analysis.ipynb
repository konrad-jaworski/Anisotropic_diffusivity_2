# %%
import torch
from matplotlib import pyplot as plt

# %%
losses=torch.load(r"C:\Users\stone\Anisotropic_diffusivity_2\results_27_11_2025\loss_logs.pth",weights_only=False)

# %%
loss_total=losses['loss_total']
loss_phys=losses['loss_phys']
loss_data=losses['loss_data']
loss_weights=['loss_weights']
weights=losses['Weights']

# %%
plt.figure(figsize=(12,6))
plt.semilogy(loss_phys)

plt.xlabel('Epoch')
plt.ylabel('Loss value')
plt.grid(alpha=0.3)
plt.title("PDE loss")
# Out:
# Text(0.5, 1.0, 'PDE loss')

# %%
plt.figure(figsize=(12,6))
plt.semilogy(loss_data)
plt.xlabel('Epoch')
plt.ylabel('Loss value')
plt.grid(alpha=0.3)
plt.title("Data loss")
# Out:
# Text(0.5, 1.0, 'Data loss')

# %%
loss_data[-1]
# Out:
# 0.11249615936254968

# %%
plt.figure(figsize=(12,6))
plt.plot(weights)
plt.xlabel('Epoch')
plt.ylabel('Loss value')
plt.grid(alpha=0.3)
plt.title("Data loss")
# Out:
# Text(0.5, 1.0, 'Data loss')
